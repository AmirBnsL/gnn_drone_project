# %%
import torch
from torch_geometric.data import InMemoryDataset

payload = torch.load("datasets/formation_a_comm_10m_a.pt")
data, slices = payload["data"], payload["slices"]
formation_names = payload["formation_names"]

dataset = InMemoryDataset()
dataset.data, dataset.slices = data, slices
print(len(dataset), dataset[0])
# Out:
# ['states', 'targets', 'labels', 'edges']

# %%
# Out:
# Dataset length: 8000
